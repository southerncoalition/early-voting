# %%
import pandas as pd
from datetime import datetime
import numpy as np

# %%
sites_file_path = './data/sites_geocoded_04182024.csv'
sites_df = pd.read_csv(sites_file_path)

# %%
sites_df['site_name'] = sites_df['site_name'].str.slice(0, 50)

# %%
dem_path = './data/combined_data_04192024.csv'
dem_df = pd.read_csv(dem_path)

# %%
import re

# %%
# Function to standardis site names for both demographic and EV plan files
def standardize_name(name):
    return re.sub(r'\W+', '', name.lower())

sites_df['standardized_site_name'] = sites_df['site_name'].apply(standardize_name)
dem_df['standardized_site_name'] = dem_df['site_name'].apply(standardize_name)

# %%
# Rename county_desc column in demographic file
dem_df.rename(columns={'county_desc': 'County'}, inplace=True)

# %%
# Fill all NAs in demographic files
dem_df.fillna(0, inplace=True)

# %%
# Merge the files based on the County, standardized_site_name, and election fields. Uses outer join to maintain all rows from both dataframes
full_df = pd.merge(dem_df,sites_df, left_on=['County', 'standardized_site_name', 'election'], right_on=['County','standardized_site_name', 'election'], how='outer')

# %%
# Create the Discrepancies column to label sites that aren't consistent between the two files
full_df['Discrepancies'] = np.where(full_df['site_name_x'].isna(), 'In EV plan, no voters',
                            np.where(full_df['site_name_y'].isna(), 'Had voters, not in EV plan', 'In EV plan, had voters'))

# %%
# Fill in site_name on rows where the wasn't an demographic file name for it, but there was a EV plan file name for it
full_df['site_name_x'] = np.where(full_df['site_name_x'].isna(), full_df['site_name_y'], full_df['site_name_x'])

# %%
full_df.to_csv("full_df.csv", index=False)

# %%
# Get a list of columns in the full_df dataframe
column_list = full_df.columns.tolist()

# %%
# List of columns to keep moving forward
columns_to_keep = ['County', 'election','site_name_x', 'address','Date', 'Time','main_site',  'site_total','n','sdr_percent','age_percent_Age 18 - 25', 'age_percent_Age 26 - 40', 'age_percent_Age 41 - 65', 'age_percent_Age Over 66', 'age_percent_NA', 'n_Age 18 - 25', 'n_Age 26 - 40', 'n_Age 41 - 65', 'n_Age Over 66', 'n_NA','ethnicity_percent_HISPANIC or LATINO', 'ethnicity_percent_NOT HISPANIC or NOT LATINO', 'ethnicity_percent_UNDESIGNATED ETHNICITY', 'n_HISPANIC or LATINO', 'n_NOT HISPANIC or NOT LATINO', 'n_UNDESIGNATED ETHNICITY', 'race_percent_ASIAN', 'race_percent_BLACK or AFRICAN AMERICAN', 'race_percent_INDIAN AMERICAN or ALASKA NATIVE', 'race_percent_OTHER', 'race_percent_TWO or MORE RACES', 'race_percent_UNDESIGNATED RACE', 'race_percent_WHITE', 'n_ASIAN', 'n_BLACK or AFRICAN AMERICAN', 'n_INDIAN AMERICAN or ALASKA NATIVE', 'n_OTHER', 'n_TWO or MORE RACES', 'n_UNDESIGNATED RACE', 'n_WHITE', 'race_percent_NATIVE HAWAIIAN or PACIFIC ISLANDER', 'n_NATIVE HAWAIIAN or PACIFIC ISLANDER', 'Latitude', 'Longitude', 'Discrepancies']

# %%
# New dataframe with only columns to keep
final_df = full_df[columns_to_keep]

# %%
from datetime import datetime

# %%
# function to calculate number of hours each site was open

def calculate_hours(time_range):
    # Check if time_range is a string
    if not isinstance(time_range, str):
        return 0  # Return 0 for non-string inputs, including NaN

    try:
        # Replace 'a.m.' with 'AM' and 'p.m.' with 'PM'
        time_range = time_range.replace('a.m.', 'AM').replace('p.m.', 'PM')

        # Split the time range into start and end times
        start_time_str, end_time_str = time_range.split(' - ')

        # Define the time format
        time_format = '%I:%M %p'

        # Convert start and end times to datetime objects
        start_time = datetime.strptime(start_time_str, time_format)
        end_time = datetime.strptime(end_time_str, time_format)

        # Calculate the duration in hours
        duration = (end_time - start_time).seconds / 3600  # Convert seconds to hours

        return duration

    except Exception as e:
        print(f"Error processing time range '{time_range}': {e}")
        return 0  # Also return 0 in case of any other error during processing

# %%
# Applying the function
final_df.loc[:,'hours_open'] = final_df.loc[:,'Time'].apply(calculate_hours)
# Out:
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_2368/3475604174.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.loc[:,'hours_open'] = final_df.loc[:,'Time'].apply(calculate_hours)

# %%
# Converting Date column to Date formate so that it can be used to divide up the days for analysis
final_df.loc[:, 'Date'] = pd.to_datetime(final_df.loc[:, 'Date'])

# %%
# Label each day with day of week
def label_day_of_week(day):
    if day == 5:
        return "Saturday"
    elif day == 6:
        return "Sunday"
    else:
        return "Weekday"

# %%
final_df['Date'] = pd.to_datetime(final_df['Date'])
# Out:
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_2368/1069453746.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['Date'] = pd.to_datetime(final_df['Date'])

# %%
final_df.loc[:, 'Day Type'] = final_df.loc[:,'Date'].dt.dayofweek.apply(label_day_of_week)
# Out:
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_2368/4268023474.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.loc[:, 'Day Type'] = final_df.loc[:,'Date'].dt.dayofweek.apply(label_day_of_week)

# %%
# Counting the number of each type of day based on these columns unique sites and election
day_counts = final_df.groupby(['County', 'site_name_x','address', 'election', 'Day Type']).size().unstack(fill_value=0)

# %%
# Renaming the resulting columns
day_counts.rename(columns={'Weekday': 'Weekday Count', 'Saturday': 'Saturday Count', 'Sunday': 'Sunday Count'}, inplace=True)

# %%
# Add Saturday and Sunday counts to get a weekend count
day_counts['Weekend Count'] = day_counts['Saturday Count'] + day_counts['Sunday Count']

# %%
# Add weekend and weekday count to get all day count
day_counts['Total Days Count'] = day_counts['Weekend Count'] + day_counts['Weekday Count']

# %%
# Need to remember why I added this step
day_counts.reset_index(inplace=True)

# %%
day_counts.head()
# Out:
# Day Type    County                                        site_name_x
# 0         ALAMANCE          ALAMANCE COUNTY BOARD OF ELECTIONS OFFICE  \
# 1         ALAMANCE          ALAMANCE COUNTY BOARD OF ELECTIONS OFFICE
# 2         ALAMANCE          ALAMANCE COUNTY BOARD OF ELECTIONS OFFICE
# 3         ALAMANCE          ALAMANCE COUNTY BOARD OF ELECTIONS OFFICE
# 4         ALAMANCE  ALAMANCE COUNTY OFFICE ANNEX BUILDING (AUDITOR...
#
# Day Type                           address election  Saturday Count
# 0         115 S MAPLE ST, GRAHAM, NC 27253  2017-10               1  \
# 1         115 S MAPLE ST, GRAHAM, NC 27253  2017-11               1
# 2         115 S MAPLE ST, GRAHAM, NC 27253  2019-10               1
# 3         115 S MAPLE ST, GRAHAM, NC 27253  2019-11               1
# 4           201 W ELM ST, GRAHAM, NC 27253  2018-11               2
#
# Day Type  Sunday Count  Weekday Count  Weekend Count  Total Days Count
# 0                    0             12              1                13
# 1                    0             12              1                13
# 2                    0             13              1                14
# 3                    0             13              1                14
# 4                    0             13              2                15

# %%
# Convert hours open to numeric
final_df.loc[:,'hours_open'] = pd.to_numeric(final_df['hours_open'], errors='coerce')

# %%
# For each site/election combo, sum the total hours open
hours_open_sum = final_df.groupby(['County', 'address', 'election'])['hours_open'].sum().reset_index(name='Total Hours Open')

# %%
stats_df = pd.merge(day_counts.reset_index(), hours_open_sum, on=['County', 'address', 'election'], how='left')

# %%
sites_dem_df = final_df.drop(columns=['Date', 'Time', 'hours_open', 'Day Type'])

# %%
sites_dem_df = sites_dem_df.drop_duplicates()

# %%
merged_df = pd.merge(sites_dem_df,stats_df, on=['County', 'site_name_x', 'address', 'election'], how='outer')

# %%
unique_times = final_df.groupby(['County','address', 'election', 'Day Type'])['Time'].unique().unstack()

# %%
unique_times = unique_times.reset_index().fillna('')

# %%
final_df_with_times = pd.merge(merged_df, unique_times, on=['County', 'address', 'election'], how='outer')

# %%
other_race_columns_n = ['n_INDIAN AMERICAN or ALASKA NATIVE', 'n_OTHER', 'n_TWO or MORE RACES', 'n_UNDESIGNATED RACE', 'n_NATIVE HAWAIIAN or PACIFIC ISLANDER']
other_race_columns_percent = ['race_percent_INDIAN AMERICAN or ALASKA NATIVE', 'race_percent_OTHER', 'race_percent_TWO or MORE RACES', 'race_percent_UNDESIGNATED RACE', 'race_percent_NATIVE HAWAIIAN or PACIFIC ISLANDER']
final_df_with_times['n_Other Race']= final_df_with_times[other_race_columns_n].sum(axis=1)
final_df_with_times['percent_Other Race']= final_df_with_times[other_race_columns_percent].sum(axis=1)

# %%
final_df_with_times['election_date'] = final_df_with_times['election'].str.replace("-", "", regex=False)

# %%
final_df_with_times.drop('index', axis=1, inplace=True)

# %%
final_df_with_times.iloc[:, 6:40] = final_df_with_times.iloc[:, 6:40].fillna(0)
final_df_with_times.iloc[:, 43:49] = final_df_with_times.iloc[:, 43:49].fillna(0)

# %%
rename_dict = {
    'County': 'County',
    'election': 'Election',
    'site_name_x': 'Site_Name',
    'address': 'Address',
    'main_site': 'CBOE_or_Alternate',
    'site_total': 'Site_Total',
    'n': 'Number_of_SDR_Voters',
    'sdr_percent': 'Percent_SDR_Voters',
    'age_percent_Age 18 - 25': 'Percent_of_Voters_Age_18-25',
    'age_percent_Age 26 - 40': 'Percent_of_Voters_Age_26-40',
    'age_percent_Age 41 - 65': 'Percent_of_Voters_Age_41-65',
    'age_percent_Age Over 66': 'Percent_of_Voters_Age_Over_66',
    'age_percent_NA': 'Percent_of_Voters_Age_NA',
    'n_Age 18 - 25': 'Number_of_Voters_Age_18-25',
    'n_Age 26 - 40': 'Number_of_Voters_Age_26-40',
    'n_Age 41 - 65': 'Number_of_Voters_Age_41-65',
    'n_Age Over 66': 'Number_of_Voters_Age_Over_66',
    'n_NA': 'Number_of_Voters_Age_NA',
    'ethnicity_percent_HISPANIC or LATINO': 'Percent_of_Voters_HISPANIC_or_LATINO',
    'ethnicity_percent_NOT HISPANIC or NOT LATINO': 'Percent_of_Voters_NOT_HISPANIC_or_NOT_LATINO',
    'ethnicity_percent_UNDESIGNATED ETHNICITY': 'Percent_of_Voters_UNDESIGNATED_ETHNICITY',
    'n_HISPANIC or LATINO': 'Number_of_Voters_HISPANIC_or_LATINO',
    'n_NOT HISPANIC or NOT LATINO': 'Number_of_Voters_NOT_HISPANIC_or_NOT_LATINO',
    'n_UNDESIGNATED ETHNICITY': 'Number_of_Voters_UNDESIGNATED_ETHNICITY',
    'race_percent_ASIAN': 'Percent_of_Voters_ASIAN',
    'race_percent_BLACK or AFRICAN AMERICAN': 'Percent_of_Voters_BLACK_or_AFRICAN_AMERICAN',
    'race_percent_INDIAN AMERICAN or ALASKA NATIVE': 'Percent_of_Voters_INDIAN_AMERICAN_or_ALASKA_NATIVE',
    'race_percent_OTHER': 'Percent_of_Voters_OTHER',
    'race_percent_TWO or MORE RACES': 'Percent_of_Voters_TWO_or_MORE_RACES',
    'race_percent_UNDESIGNATED RACE': 'Percent_of_Voters_UNDESIGNATED_RACE',
    'race_percent_WHITE': 'Percent_of_Voters_WHITE',
    'percent_Other Race': 'Percent_of_Voters_Other_Race',
    'n_ASIAN': 'Number_of_Voters_ASIAN',
    'n_BLACK or AFRICAN AMERICAN': 'Number_of_Voters_BLACK_or_AFRICAN_AMERICAN',
    'n_INDIAN AMERICAN or ALASKA NATIVE': 'Number_of_Voters_INDIAN_AMERICAN_or_ALASKA_NATIVE',
    'n_OTHER': 'Number_of_Voters_OTHER',
    'n_TWO or MORE RACES': 'Number_of_Voters_TWO_or_MORE_RACES',
    'n_UNDESIGNATED RACE': 'Number_of_Voters_UNDESIGNATED_RACE',
    'n_WHITE': 'Number_of_Voters_WHITE',
    'n_Other Race': 'Number_of_Voters_Other_Race',
    'race_percent_NATIVE HAWAIIAN or PACIFIC ISLANDER': 'Percent_of_Voters_NATIVE_HAWAIIAN_or_PACIFIC_ISLANDER',
    'n_NATIVE HAWAIIAN or PACIFIC ISLANDER': 'Number_of_Voters_NATIVE_HAWAIIAN_or_PACIFIC_ISLANDER',
    'Latitude': 'Latitude',
    'Longitude': 'Longitude',
    'Saturday Count': 'Number_of_Saturdays_Open',
    'Sunday Count': 'Number_of_Sundays_Open',
    'Weekday Count': 'Number_of_Weekdays_Open',
    'Weekend Count': 'Number_of_Weekend_Days_Open',
    'Total Days Count': 'Total_Days_Open',
    'Total Hours Open': 'Total_Hours_Open',
    'Saturday': 'Saturday_Time_Ranges',
    'Sunday': 'Sunday_Time_Ranges',
    'Weekday': 'Weekday_Time_Ranges',
    'election_date': 'Election_Date',
}

# %%
final_df_with_times.rename(columns=rename_dict, inplace=True)

# %%
reordered_df = ['County', 'Election', 'Site_Name','Discrepancies', 'Address', 'CBOE_or_Alternate',
       'Site_Total', 'Number_of_SDR_Voters', 'Percent_SDR_Voters',
       'Percent_of_Voters_Age_18-25', 'Percent_of_Voters_Age_26-40',
       'Percent_of_Voters_Age_41-65', 'Percent_of_Voters_Age_Over_66',
       'Percent_of_Voters_Age_NA', 'Number_of_Voters_Age_18-25',
       'Number_of_Voters_Age_26-40', 'Number_of_Voters_Age_41-65',
       'Number_of_Voters_Age_Over_66', 'Number_of_Voters_Age_NA',
       'Percent_of_Voters_HISPANIC_or_LATINO',
       'Percent_of_Voters_NOT_HISPANIC_or_NOT_LATINO',
       'Percent_of_Voters_UNDESIGNATED_ETHNICITY',
       'Number_of_Voters_HISPANIC_or_LATINO',
       'Number_of_Voters_NOT_HISPANIC_or_NOT_LATINO',
       'Number_of_Voters_UNDESIGNATED_ETHNICITY', 'Percent_of_Voters_ASIAN',
       'Percent_of_Voters_BLACK_or_AFRICAN_AMERICAN',
       'Percent_of_Voters_INDIAN_AMERICAN_or_ALASKA_NATIVE',
       'Percent_of_Voters_OTHER', 'Percent_of_Voters_TWO_or_MORE_RACES',
       'Percent_of_Voters_UNDESIGNATED_RACE', 'Percent_of_Voters_WHITE','Percent_of_Voters_NATIVE_HAWAIIAN_or_PACIFIC_ISLANDER',
       'Percent_of_Voters_Other_Race',
       'Number_of_Voters_ASIAN', 'Number_of_Voters_BLACK_or_AFRICAN_AMERICAN',
       'Number_of_Voters_INDIAN_AMERICAN_or_ALASKA_NATIVE',
       'Number_of_Voters_OTHER', 'Number_of_Voters_TWO_or_MORE_RACES',
       'Number_of_Voters_UNDESIGNATED_RACE', 'Number_of_Voters_WHITE', 'Number_of_Voters_NATIVE_HAWAIIAN_or_PACIFIC_ISLANDER', 
       'Number_of_Voters_Other_Race', 
       'Latitude',
       'Longitude', 'Number_of_Saturdays_Open',
       'Number_of_Sundays_Open', 'Number_of_Weekdays_Open',
       'Number_of_Weekend_Days_Open', 'Total_Days_Open', 'Total_Hours_Open',
       'Saturday_Time_Ranges', 'Sunday_Time_Ranges', 'Weekday_Time_Ranges',
       'Election_Date']

# %%
final_df_with_times = final_df_with_times[reordered_df]

# %%
final_output_file = 'site_stats_' + datetime.today().strftime('%Y-%m-%d') + '_discrepancies.csv'
final_output_file
# Out:
# 'site_stats_2024-04-22_discrepancies.csv'

# %%
final_df_with_times.to_csv(final_output_file, index=False)

# %%
final_df_with_times.columns
# Out:
# Index(['County', 'Election', 'Site_Name', 'Address', 'CBOE_or_Alternate',
#        'Site_Total', 'Number_of_SDR_Voters', 'Percent_SDR_Voters',
#        'Percent_of_Voters_Age_18-25', 'Percent_of_Voters_Age_26-40',
#        'Percent_of_Voters_Age_41-65', 'Percent_of_Voters_Age_Over_66',
#        'Percent_of_Voters_Age_NA', 'Number_of_Voters_Age_18-25',
#        'Number_of_Voters_Age_26-40', 'Number_of_Voters_Age_41-65',
#        'Number_of_Voters_Age_Over_66', 'Number_of_Voters_Age_NA',
#        'Percent_of_Voters_HISPANIC_or_LATINO',
#        'Percent_of_Voters_NOT_HISPANIC_or_NOT_LATINO',
#        'Percent_of_Voters_UNDESIGNATED_ETHNICITY',
#        'Number_of_Voters_HISPANIC_or_LATINO',
#        'Number_of_Voters_NOT_HISPANIC_or_NOT_LATINO',
#        'Number_of_Voters_UNDESIGNATED_ETHNICITY', 'Percent_of_Voters_ASIAN',
#        'Percent_of_Voters_BLACK_or_AFRICAN_AMERICAN',
#        'Percent_of_Voters_INDIAN_AMERICAN_or_ALASKA_NATIVE',
#        'Percent_of_Voters_OTHER', 'Percent_of_Voters_TWO_or_MORE_RACES',
#        'Percent_of_Voters_UNDESIGNATED_RACE', 'Percent_of_Voters_WHITE',
#        'Number_of_Voters_ASIAN', 'Number_of_Voters_BLACK_or_AFRICAN_AMERICAN',
#        'Number_of_Voters_INDIAN_AMERICAN_or_ALASKA_NATIVE',
#        'Number_of_Voters_OTHER', 'Number_of_Voters_TWO_or_MORE_RACES',
#        'Number_of_Voters_UNDESIGNATED_RACE', 'Number_of_Voters_WHITE',
#        'Percent_of_Voters_NATIVE_HAWAIIAN_or_PACIFIC_ISLANDER',
#        'Number_of_Voters_NATIVE_HAWAIIAN_or_PACIFIC_ISLANDER', 'Latitude',
#        'Longitude', 'Discrepencies', 'Number_of_Saturdays_Open',
#        'Number_of_Sundays_Open', 'Number_of_Weekdays_Open',
#        'Number_of_Weekend_Days_Open', 'Total_Days_Open', 'Total_Hours_Open',
#        'Saturday_Time_Ranges', 'Sunday_Time_Ranges', 'Weekday_Time_Ranges',
#        'Number_of_Voters_Other_Race', 'Percent_of_Voters_Other_Race',
#        'Election_Date'],
#       dtype='object')

# %%
# ISOCHRONE
import requests
import geojson
import time

# %%
df_unique = final_df_with_times[['County', 'Address', 'Latitude', 'Longitude']].drop_duplicates()

# %%
df_unique.head(), df_unique.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[535], line 1
# ----> 1 df_unique.head(), df_unique.shape
#
# NameError: name 'df_unique' is not defined

# %%
MAPBOX_API_TOKEN = 'pk.eyJ1Ijoia2xhdXNtYXlyIiwiYSI6ImNsM20xZWFxejAwNmkza29mcHptN243aTYifQ.lfLe-OcdZ89adHFcD7r9tQ'

BASE_URL = 'https://api.mapbox.com/isochrone/v1/mapbox/walking/'

# %%
def create_isochrone(lat, lon):
    params = {
        'contours_minutes': [30],
        'polygons': 'true',
        'access_token': MAPBOX_API_TOKEN,
    }
    response = requests.get(f'{BASE_URL}{lon},{lat}', params=params)
    return response.json()

# %%
isochrone_features = []

for index, row in df_unique.iterrows():
    print(row)
    time.sleep(0.1)
    isochrone = create_isochrone(row['Latitude'], row['Longitude'])
    if 'features' in isochrone:
        # Extract the first feature's geometry from the isochrone response
        isochrone_geometry = isochrone['features'][0]['geometry']
        isochrone_feature = geojson.Feature(geometry=isochrone_geometry)
        # Here, you can add properties based on the row's data if needed
        isochrone_feature['properties'] = {'County': row['County'], 'Address': row['Address']}
        isochrone_features.append(isochrone_feature)

output_geojson = geojson.FeatureCollection(isochrone_features)
output_file_path = '30_min_walking.geojson'

with open(output_file_path, 'w') as output_file:
    geojson.dump(output_geojson, output_file, indent=2)

print(f'Isochrones created and saved to {output_file_path}')
# Out:
# County                                                ALAMANCE
# Address      ALAMANCE COUNTY BOARD OF ELECTIONS OFFICE, 115...
# Latitude                                             36.067659
# Longitude                                           -79.402746
# Name: 0, dtype: object
# County                                                ALAMANCE
# Address      COURT SERVICE BUILDING, 201 W ELM ST, GRAHAM, ...
# Latitude                                              36.06959
# Longitude                                           -79.402183
# Name: 3, dtype: object
# County                                             ALAMANCE
# Address      COURT SERVICES, 201 W ELM ST, GRAHAM, NC 27253
# Latitude                                           36.06959
# Longitude                                        -79.402183
# Name: 4, dtype: object
# County                                                ALAMANCE
# Address      ELMIRA COMMUNITY CENTER, 810 WICKER ST, BURLIN...
# Latitude                                             36.106984
# Longitude                                           -79.442567
# Name: 5, dtype: object
# County                                                ALAMANCE
# Address      ELON SOUTH CAMPUS GYM, 329 S ANTIOCH AVE, ELON...
# Latitude                                             36.097551
# Longitude                                           -79.501101
# Name: 7, dtype: object
# County                                                ALAMANCE
# Address      GRAHAM RECREATION CENTER, 311 COLLEGE ST, GRAH...
# Latitude                                             36.076683
# Longitude                                           -79.406297
# Name: 8, dtype: object
# County                                                ALAMANCE
# Address      HOLLY HILL MALL, 309 HUFFMAN MILL RD # 300, BU...
# Latitude                                             36.078706
# Longitude                                           -79.487503
# Name: 10, dtype: object
# County                                                ALAMANCE
# Address      KERNODLE SENIOR CENTER, 1535 S MEBANE ST, BURL...
# Latitude                                             36.079698
# Longitude                                           -79.451182
# Name: 14, dtype: object
# County                                                ALAMANCE
# Address      MEBANE ARTS AND COMMUN ITY CENTER, 622 CORREGI...
# Latitude                                             36.085803
# Longitude                                           -79.284008
# Name: 18, dtype: object
# County                                               ALEXANDER
# Address      ALEXANDER COUNTY BOARD OF ELECTIONS, OFFICE, 3...
# Latitude                                             35.923548
# Longitude                                           -81.176301
# Name: 23, dtype: object
# County                                               ALEXANDER
# Address      ALEXANDER SENIOR CENTER, 730 SW 7TH ST, TAYLOR...
# Latitude                                             35.912831
# Longitude                                           -81.188228
# Name: 28, dtype: object
# County                                               ALEXANDER
# Address      BETHLEHEM COMMUNITY FIRE/RESCUE, 7373 NC HWY 1...
# Latitude                                             35.843571
# Longitude                                           -81.308952
# Name: 31, dtype: object
# County                                               ALEXANDER
# Address      FMR ENERGY UNITED BUILDING, 431 RURITAN PARK R...
# Latitude                                             35.862112
# Longitude                                           -81.045815
# Name: 37, dtype: object
# County                                               ALEXANDER
# Address      HIDDENITE VOLUNTEER FIRE DEPARTMENT, 4975 E NC...
# Latitude                                             35.902221
# Longitude                                           -81.092841
# Name: 40, dtype: object
# County                                               ALLEGHANY
# Address      ALLEGHANY COUNTY BOARD OF ELECTIONS, OFFICE, 3...
# Latitude                                              36.50134
# Longitude                                           -81.117081
# Name: 43, dtype: object
# County                                               ALLEGHANY
# Address      ALLEGHANY COUNTY BOARD OF ELECTIONS, OFFICE, 3...
# Latitude                                              36.50134
# Longitude                                           -81.117081
# Name: 49, dtype: object
# County                                                   ANSON
# Address      ANSON COUNTY BOARD OF ELECTIONS OFFICE, 402 MO...
# Latitude                                             34.962256
# Longitude                                           -80.075886
# Name: 50, dtype: object
# County                                                    ASHE
# Address      ASHE AGRICULTURAL SERVICES BUILDING, 134 GOVER...
# Latitude                                             36.419241
# Longitude                                           -81.460212
# Name: 58, dtype: object
# County                                                    ASHE
# Address      ASHE AGRICULTURAL SERVICES BUILDING, 134 GOVER...
# Latitude                                             36.420403
# Longitude                                           -81.473438
# Name: 59, dtype: object
# County                                                    ASHE
# Address      ASHE COUNTY BOARD OF ELECTIONS OFFICE, 150 GOV...
# Latitude                                             36.418411
# Longitude                                           -81.459066
# Name: 61, dtype: object
# County                                                    ASHE
# Address      FLEETWOOD FIRE DEPARTMENT, 9005 US HWY 221 S, ...
# Latitude                                             36.310914
# Longitude                                           -81.509122
# Name: 65, dtype: object
# County                                                   AVERY
# Address      AVERY COUNTY BOARD OF ELECTIONS OFFICE, 200 MO...
# Latitude                                             36.086644
# Longitude                                           -81.926504
# Name: 66, dtype: object
# County                                                   AVERY
# Address      AVERY COUNTY DIVE IN POOL COMPLEX, 220 SHADY S...
# Latitude                                             36.082301
# Longitude                                           -81.924196
# Name: 73, dtype: object
# County                                                   AVERY
# Address      AVERY COUNTY SENIOR CENTER, 1655 SCHULTZ ST, N...
# Latitude                                             36.085562
# Longitude                                           -81.926333
# Name: 74, dtype: object
# County                                                BEAUFORT
# Address      AURORA - AURORA COMMUNITY CENTER, 442 3RD ST, ...
# Latitude                                              35.30391
# Longitude                                            -76.78546
# Name: 76, dtype: object
# County                                                BEAUFORT
# Address      BEAUFORT COUNTY BOARD OF ELECTIONS OFFICE, 130...
# Latitude                                             35.549611
# Longitude                                           -77.036244
# Name: 84, dtype: object
# County                                                BEAUFORT
# Address      BELHAVEN - JOHN A WILKINSON CENTER, 144 W MAIN...
# Latitude                                             35.541023
# Longitude                                           -76.623038
# Name: 94, dtype: object
# County                                                BEAUFORT
# Address      CHOCOWINITY FIRE DEPARTMENT, 512 E NC HWY 33, ...
# Latitude                                             35.508793
# Longitude                                           -77.093229
# Name: 102, dtype: object
# County                                                  BERTIE
# Address      BERTIE COUNTY BOARD OF ELECTIONS OFFICE, 210 W...
# Latitude                                             36.000624
# Longitude                                           -76.952552
# Name: 107, dtype: object
# County                                                  BERTIE
# Address      LEWISTON, 103 W CHURCH ST, LEWISTON WOODVILLE,...
# Latitude                                             36.122991
# Longitude                                           -77.177139
# Name: 116, dtype: object
# County                                                  BERTIE
# Address      POWELLSVILLE TOWN HALL, 106 E MAIN ST, POWELLS...
# Latitude                                             36.225194
# Longitude                                           -76.932338
# Name: 117, dtype: object
# County                                                  BLADEN
# Address      BAY TREE FIRE DEPARTMENT, 12717 NC 41 HWY W, H...
# Latitude                                             34.687943
# Longitude                                           -78.415992
# Name: 123, dtype: object
# County                                                  BLADEN
# Address      BLADEN COUNTY BOARD OF ELECTIONS OFFICE, 301 S...
# Latitude                                             34.626245
# Longitude                                           -78.604804
# Name: 124, dtype: object
# County                                                  BLADEN
# Address      BLADEN COUNTY PUBLIC LIBRARY, 111 N CYPRESS ST...
# Latitude                                             34.629514
# Longitude                                           -78.604184
# Name: 130, dtype: object
# County                                                  BLADEN
# Address      BLADEN COUNTY RECREATION DEPT. (GYM), 803 W KI...
# Latitude                                             34.629826
# Longitude                                           -78.614737
# Name: 133, dtype: object
# County                                                  BLADEN
# Address      BLADENBORO, 508 MARTIN LUTHER KING JR DR, BLAD...
# Latitude                                             34.537933
# Longitude                                           -78.779263
# Name: 134, dtype: object
# County                                                BLADEN
# Address      BLADENBORO, 818 S MAIN ST, BLADENBORO, NC 28320
# Latitude                                           34.531737
# Longitude                                         -78.796184
# Name: 138, dtype: object
# County                                                  BLADEN
# Address      BOOKER T WASHINGTON PRIMARY SCHOOL, 66 BOOKER ...
# Latitude                                             34.500622
# Longitude                                           -78.667486
# Name: 139, dtype: object
# County                                                  BLADEN
# Address      DUBLIN TOWN HALL, 7386 ALBERT ST, DUBLIN, NC 2...
# Latitude                                              34.65784
# Longitude                                           -78.724526
# Name: 140, dtype: object
# County                                     BLADEN
# Address      DUBLIN, 120 2ND ST, DUBLIN, NC 28332
# Latitude                                34.658311
# Longitude                              -78.728202
# Name: 141, dtype: object
# County                                                  BLADEN
# Address      EAST ARCADIA, 1472 EAST ARCADIA RD, RIEGELWOOD...
# Latitude                                             34.382908
# Longitude                                           -78.327702
# Name: 143, dtype: object
# County                                                  BLADEN
# Address      EAST ARCADIA, 1516 EAST ARCADIA RD, RIEGELWOOD...
# Latitude                                             34.382643
# Longitude                                           -78.328423
# Name: 147, dtype: object
# County                                                  BLADEN
# Address      TAR HEEL MUNICIPAL BLDG., 14867 NC 87 HWY W, T...
# Latitude                                              34.73505
# Longitude                                           -78.794922
# Name: 149, dtype: object
# County                                       BRUNSWICK
# Address      BELVILLE, 63 RIVER RD, BELVILLE, NC 28451
# Latitude                                     34.229671
# Longitude                                   -77.991129
# Name: 153, dtype: object
# County                                               BRUNSWICK
# Address      BRUNSWICK CENTER AT SHALLOTTE, 3620 EXPRESS DR...
# Latitude                                             33.985819
# Longitude                                           -78.393866
# Name: 154, dtype: object
# County                                               BRUNSWICK
# Address      BRUNSWICK COMMUNITY COLLEGE, 50 COLLEGE RD # A...
# Latitude                                             34.040451
# Longitude                                           -78.231448
# Name: 156, dtype: object
# County                                               BRUNSWICK
# Address      BRUNSWICK COUNTY BOARD OF ELECTIONS, OFFICE, 7...
# Latitude                                             34.057402
# Longitude                                           -78.164504
# Name: 157, dtype: object
# County                                               BRUNSWICK
# Address      COOPERATIVE EXTENSION, 25 REFERENDUM DR NE # N...
# Latitude                                             34.056751
# Longitude                                           -78.165751
# Name: 161, dtype: object
# County                                               BRUNSWICK
# Address      HOLDEN BEACH EOC BUILDING, 1044 SABBATH HOME R...
# Latitude                                             33.930268
# Longitude                                           -78.269468
# Name: 166, dtype: object
# County                                               BRUNSWICK
# Address      LELAND CULTURAL ARTS CENTER, 1212 MAGNOLIA VIL...
# Latitude                                             34.213159
# Longitude                                           -78.028903
# Name: 167, dtype: object
# County                                               BRUNSWICK
# Address      LELAND TOWN HALL, 102 TOWN HALL DR, LELAND, NC...
# Latitude                                             34.189984
# Longitude                                           -77.987948
# Name: 173, dtype: object
# County                                               BRUNSWICK
# Address      NATIONAL GUARD ARMORY, 5050 MAIN ST, SHALLOTTE...
# Latitude                                             33.967656
# Longitude                                            -78.39338
# Name: 174, dtype: object
# County                                               BRUNSWICK
# Address      NAVASSA COMMUNITY BUILDING, 338 MAIN ST, NAVAS...
# Latitude                                             34.256783
# Longitude                                           -78.010668
# Name: 178, dtype: object
# County                                               BRUNSWICK
# Address      OAK ISLAND RECREATION CENTER, 3003 E OAK ISLAN...
# Latitude                                             33.917167
# Longitude                                           -78.130876
# Name: 179, dtype: object
# County                                               BRUNSWICK
# Address      SHALLOTTE COMMONS, 5051 MAIN ST # 4, SHALLOTTE...
# Latitude                                             33.965713
# Longitude                                            -78.39249
# Name: 180, dtype: object
# County                                               BRUNSWICK
# Address      SOUTH BRUNSWICK ISLANDS CENTER - BCC, 9400 OCE...
# Latitude                                             33.922489
# Longitude                                           -78.578911
# Name: 181, dtype: object
# County                                               BRUNSWICK
# Address      SOUTHWEST BRUNSWICK BRANCH LIBRARY, 9400 OCEAN...
# Latitude                                             33.922489
# Longitude                                           -78.578911
# Name: 183, dtype: object
# County                                               BRUNSWICK
# Address      ST JAMES COMMUNITY CENTER, 4136 SOUTHPORT-SUPP...
# Latitude                                              33.96343
# Longitude                                           -78.089662
# Name: 187, dtype: object
# County                                               BRUNSWICK
# Address      THE BRUNSWICK CENTER AT CALABASH, 10050 BEACH ...
# Latitude                                             33.891244
# Longitude                                           -78.570787
# Name: 188, dtype: object
# County                                               BRUNSWICK
# Address      THE BRUNSWICK CENTER AT LELAND, 121 TOWN HALL ...
# Latitude                                             34.238832
# Longitude                                           -78.008421
# Name: 189, dtype: object
# County                                               BRUNSWICK
# Address      THE BRUNSWICK CENTER AT SOUTHPORT, 1513 N HOWE...
# Latitude                                             33.937074
# Longitude                                           -78.028417
# Name: 190, dtype: object
# County                                               BRUNSWICK
# Address      THE BRUNSWICK CENTER AT SUPPLY, 101 STONE CHIM...
# Latitude                                             34.016611
# Longitude                                           -78.268838
# Name: 197, dtype: object
# County                                                BUNCOMBE
# Address      AB TECH (MISSION HEALTH/CONFERENCE CTR), 16 FE...
# Latitude                                              35.57163
# Longitude                                           -82.556114
# Name: 198, dtype: object
# County                                                BUNCOMBE
# Address      ASHEVILLE MALL, 3 S TUNNEL RD, ASHEVILLE, NC 2...
# Latitude                                             35.581022
# Longitude                                           -82.526363
# Name: 199, dtype: object
# County                                                BUNCOMBE
# Address      ASHEVILLE OUTLETS, 800 BREVARD RD, ASHEVILLE, ...
# Latitude                                             35.527208
# Longitude                                           -82.603682
# Name: 204, dtype: object
# County                                                BUNCOMBE
# Address      AVERY'S CREEK COMMUNITY CENTER, 899 GLENN BRID...
# Latitude                                              35.46383
# Longitude                                           -82.574244
# Name: 205, dtype: object
# County                                                BUNCOMBE
# Address      BEE TREE FIRE DEPARTMENT, 510 BEE TREE RD, SWA...
# Latitude                                             35.612183
# Longitude                                           -82.420637
# Name: 206, dtype: object
# County                                                BUNCOMBE
# Address      BLACK MOUNTAIN BRANCH LIBRARY, 105 N DOUGHERTY...
# Latitude                                              35.61617
# Longitude                                           -82.322763
# Name: 208, dtype: object
# County                                                BUNCOMBE
# Address      BUNCOMBE COUNTY BOARD OF ELECTIONS, OFFICE, 77...
# Latitude                                             35.581195
# Longitude                                           -82.554254
# Name: 215, dtype: object
# County                                                BUNCOMBE
# Address      BUNCOMBE COUNTY PERMITS & INSPECTION, 30 VALLE...
# Latitude                                              35.59582
# Longitude                                           -82.547074
# Name: 217, dtype: object
# County                                                BUNCOMBE
# Address      DR. WESLEY GRANT SR - SOUTHSIDE CTR., 285 LIVI...
# Latitude                                             35.577946
# Longitude                                           -82.562253
# Name: 218, dtype: object
# County                                                BUNCOMBE
# Address      DR. WESLEY GRANT SR - SOUTHSIDE CTR., 285 LIVI...
# Latitude                                             35.577946
# Longitude                                           -82.562253
# Name: 222, dtype: object
# County                                                BUNCOMBE
# Address      EAST ASHEVILLE BRANCH LIBRARY, 3 AVON RD, ASHE...
# Latitude                                             35.588216
# Longitude                                           -82.503319
# Name: 224, dtype: object
# County                                                BUNCOMBE
# Address      ELECTIONS SERVICES WAREHOUSE, 50 COXE AVE, ASH...
# Latitude                                             35.592581
# Longitude                                           -82.554655
# Name: 226, dtype: object
# County                                                BUNCOMBE
# Address      ENKA/CANDLER BRANCH LIBRARY, 1404 SAND HILL RD...
# Latitude                                              35.53889
# Longitude                                             -82.6521
# Name: 230, dtype: object
# County                                                BUNCOMBE
# Address      FAIRVIEW BRANCH LIBRARY, 1 TAYLOR RD, FAIRVIEW...
# Latitude                                             35.524957
# Longitude                                           -82.413608
# Name: 237, dtype: object
# County                                                BUNCOMBE
# Address      FAIRVIEW COMMUNITY CENTER, 1357 CHARLOTTE HWY,...
# Latitude                                             35.523462
# Longitude                                           -82.410136
# Name: 242, dtype: object
# County                                                BUNCOMBE
# Address      FRIENDSHIP COMMUNITY CENTER, 142 SHILOH RD, AS...
# Latitude                                             35.549355
# Longitude                                           -82.527674
# Name: 243, dtype: object
# County                                                BUNCOMBE
# Address      HARRAH'S CHEROKEE CENTER ASHEVILLE, 87 HAYWOOD...
# Latitude                                             35.597623
# Longitude                                           -82.555611
# Name: 244, dtype: object
# County                                                BUNCOMBE
# Address      LAND OF SKY REGIONAL COUNCIL, 339 NEW LEICESTE...
# Latitude                                             35.601459
# Longitude                                           -82.621712
# Name: 245, dtype: object
# County                                                BUNCOMBE
# Address      LEICESTER BRANCH LIBRARY, 1561 ALEXANDER RD, L...
# Latitude                                             35.658606
# Longitude                                           -82.694621
# Name: 246, dtype: object
# County                                                BUNCOMBE
# Address      LEICESTER COMMUNITY CENTER, 2979 NEW LEICESTER...
# Latitude                                             35.657369
# Longitude                                           -82.713786
# Name: 250, dtype: object
# County                                                BUNCOMBE
# Address      MURPHY-OAKLEY RECREATION CTR, 749 FAIRVIEW RD,...
# Latitude                                             35.564203
# Longitude                                           -82.513552
# Name: 252, dtype: object
# County                                                BUNCOMBE
# Address      NEW HOPE PRESBYTERIAN CHURCH, 3070 SWEETEN CRE...
# Latitude                                             35.504409
# Longitude                                            -82.51795
# Name: 253, dtype: object
# County                                                BUNCOMBE
# Address      NORTH ASHEVILLE BRANCH LIBRARY, 1030 MERRIMON ...
# Latitude                                             35.632684
# Longitude                                           -82.555574
# Name: 254, dtype: object
# County                                                BUNCOMBE
# Address      PACK MEMORIAL LIBRARY, 67 HAYWOOD ST, ASHEVILL...
# Latitude                                             35.596641
# Longitude                                            -82.55485
# Name: 259, dtype: object
# County                                                BUNCOMBE
# Address      POLE CREEK BAPTIST CHURCH, 96 SNOW HILL CHURCH...
# Latitude                                             35.570315
# Longitude                                           -82.713599
# Name: 260, dtype: object
# County                                                BUNCOMBE
# Address      REYNOLDS VILLAGE, 50 N MERRIMON AVE # 107, ASH...
# Latitude                                             35.641635
# Longitude                                           -82.576947
# Name: 261, dtype: object
# County                                                BUNCOMBE
# Address      REYNOLDS VILLAGE, 61 N MERRIMON AVE # 105, ASH...
# Latitude                                             35.642695
# Longitude                                           -82.576679
# Name: 262, dtype: object
# County                                                BUNCOMBE
# Address      SOUTH BUNCOMBE BRANCH LIBRARY, 260 OVERLOOK RD...
# Latitude                                             35.488169
# Longitude                                           -82.536973
# Name: 263, dtype: object
# County                                                BUNCOMBE
# Address      THE MONTFORD BUILDING, 90 MONTFORD AVE, ASHEVI...
# Latitude                                             35.597878
# Longitude                                           -82.561104
# Name: 270, dtype: object
# County                                                BUNCOMBE
# Address      TURTLE CREEK SHOPPING CENTER, 23 TURTLE CREEK ...
# Latitude                                             35.507187
# Longitude                                           -82.524489
# Name: 271, dtype: object
# County                                                BUNCOMBE
# Address      UNIVERSITY OF NORTH CAROLINA ASHEVILLE, 1 UNIV...
# Latitude                                             35.617006
# Longitude                                           -82.565412
# Name: 272, dtype: object
# County                                                BUNCOMBE
# Address      WEAVERVILLE COMMUNITY CENTER, 60 LAKESHORE DR,...
# Latitude                                             35.690549
# Longitude                                           -82.569068
# Name: 274, dtype: object
# County                                                BUNCOMBE
# Address      WEAVERVILLE TOWN HALL, 30 S MAIN ST, WEAVERVIL...
# Latitude                                              35.69558
# Longitude                                           -82.559337
# Name: 277, dtype: object
# County                                                BUNCOMBE
# Address      WEST ASHEVILLE BRANCH LIBRARY, 942 HAYWOOD AVE...
# Latitude                                             35.580787
# Longitude                                           -82.601698
# Name: 283, dtype: object
# County                                                BUNCOMBE
# Address      WEST ASHEVILLE BRANCH LIBRARY, 942 HAYWOOD RD,...
# Latitude                                             35.580787
# Longitude                                           -82.601698
# Name: 286, dtype: object
# County                                                BUNCOMBE
# Address      WEST ASHEVILLE COMMUNITY CENTER, 970 HAYWOOD R...
# Latitude                                              35.58092
# Longitude                                            -82.60204
# Name: 289, dtype: object
# County                                                BUNCOMBE
# Address      WOODFIN COMMUNITY CENTER, 23 COMMUNITY ST, ASH...
# Latitude                                             35.634814
# Longitude                                           -82.594391
# Name: 290, dtype: object
# County                                                   BURKE
# Address      BURKE COUNTY BOARD OF ELECTIONS OFFICE, 2128 S...
# Latitude                                             35.724547
# Longitude                                           -81.660844
# Name: 292, dtype: object
# County                                                   BURKE
# Address      BURKE COUNTY LIBRARY/SENIOR CENTER, 101 MAIN A...
# Latitude                                             35.709885
# Longitude                                           -81.424593
# Name: 302, dtype: object
# County                                                   BURKE
# Address      GLEN ALPINE TOWN HALL, 103 PITTS ST, GLEN ALPI...
# Latitude                                             35.729354
# Longitude                                           -81.779087
# Name: 310, dtype: object
# County                                                   BURKE
# Address      HILDEBRAN METHODIST CHURCH, 110 S CENTER ST, H...
# Latitude                                             35.713829
# Longitude                                           -81.424078
# Name: 317, dtype: object
# County                                                   BURKE
# Address      RUTHERFORD COLLEGE TOWN HALL, 980 MALCOLM BLVD...
# Latitude                                             35.752619
# Longitude                                           -81.525393
# Name: 318, dtype: object
# County                                                   BURKE
# Address      SENIOR CENTER, 501 N GREEN ST # 100, MORGANTON...
# Latitude                                              35.74846
# Longitude                                            -81.69847
# Name: 327, dtype: object
# County                                                CABARRUS
# Address      CABARRUS ARENA AND EVENTS CENTER, 4751 NC HWY ...
# Latitude                                             35.389427
# Longitude                                           -80.501297
# Name: 336, dtype: object
# County                                                CABARRUS
# Address      CABARRUS BANK BUILDING, 201 WEST AVE, KANNAPOL...
# Latitude                                             35.496689
# Longitude                                           -80.626033
# Name: 337, dtype: object
# County                                                CABARRUS
# Address      CABARRUS COUNTY BOARD OF ELECTIONS OFFICE, 369...
# Latitude                                             35.420272
# Longitude                                           -80.590587
# Name: 338, dtype: object
# County                                                CABARRUS
# Address      CONCORD FIRE STATION #9, 1020 IVEY CLINE RD, C...
# Latitude                                              35.40215
# Longitude                                           -80.701932
# Name: 345, dtype: object
# County                                                CABARRUS
# Address      COPPERFIELD CENTRE, 349 COPPERFIELD BLVD # F, ...
# Latitude                                              35.44724
# Longitude                                            -80.59995
# Name: 347, dtype: object
# County                                                CABARRUS
# Address      EMBASSY SUITES, 5400 JOHN Q. HAMMONS DR NW, CO...
# Latitude                                             35.365323
# Longitude                                           -80.701516
# Name: 348, dtype: object
# County                                                CABARRUS
# Address      HARRISBURG LIBRARY, 201 SIMS PKWY, HARRISBURG,...
# Latitude                                             35.318221
# Longitude                                           -80.658927
# Name: 349, dtype: object
# County                                                CABARRUS
# Address      HARRISBURG PRESBYTERIAN CHURCH, 4815 HIGHWAY 4...
# Latitude                                             35.321135
# Longitude                                            -80.65606
# Name: 350, dtype: object
# County                                                CABARRUS
# Address      KANNAPOLIS TRAIN DEPOT, 201 S MAIN ST, KANNAPO...
# Latitude                                             35.496057
# Longitude                                           -80.624822
# Name: 351, dtype: object
# County                                                CABARRUS
# Address      NORTHERN PLAZA, 840 CONCORD PKWY, CONCORD, NC ...
# Latitude                                             35.395131
# Longitude                                           -80.615794
# Name: 354, dtype: object
# County                                                CABARRUS
# Address      SHOPPES AT KINGS GRANT, 10099 WEDDINGTON RD # ...
# Latitude                                             35.362975
# Longitude                                           -80.711826
# Name: 355, dtype: object
# County                                                CALDWELL
# Address      CALDWELL COUNTY BOARD OF ELECTIONS OFFICE, 120...
# Latitude                                             35.922155
# Longitude                                           -81.523714
# Name: 356, dtype: object
# County                                                CALDWELL
# Address      CITY/COUNTY CHAMBERS ROOM, 905 WEST AVE, LENOI...
# Latitude                                              35.91402
# Longitude                                           -81.538985
# Name: 357, dtype: object
# County                                          CALDWELL
# Address      CITY/COUNTY, 905 WEST AVE, LENOIR, NC 28645
# Latitude                                        35.91402
# Longitude                                     -81.538985
# Name: 359, dtype: object
# County                                                CALDWELL
# Address      RESOURCE CENTER, 120 HOSPITAL AVE, LENOIR, NC ...
# Latitude                                             35.922155
# Longitude                                           -81.523714
# Name: 360, dtype: object
# County                                                CALDWELL
# Address      SHUFORD RECREATION CENTER, 56 PINEWOOD RD, GRA...
# Latitude                                             35.812534
# Longitude                                           -81.439523
# Name: 365, dtype: object
# County                                                  CAMDEN
# Address      CAMDEN COUNTY BOARD OF ELECTIONS OFFICE, 117 N...
# Latitude                                             36.329767
# Longitude                                           -76.174796
# Name: 374, dtype: object
# County                                                  CAMDEN
# Address      SHERIFF'S SATELLITE OFFICE, 105 HALSTEAD ST, S...
# Latitude                                             36.445513
# Longitude                                            -76.33155
# Name: 384, dtype: object
# County                                                CARTERET
# Address      CARTERET COUNTY BOARD OF ELECTIONS OFFICE, 170...
# Latitude                                             34.728606
# Longitude                                           -76.639015
# Name: 385, dtype: object
# County                                                CARTERET
# Address      CARTERET COUNTY BOARD OF ELECTIONS OFFICE, 170...
# Latitude                                              34.72871
# Longitude                                           -76.639023
# Name: 386, dtype: object
# County                                                CARTERET
# Address      CARTERET COUNTY BOARD OF ELECTIONS OFFICE, 170...
# Latitude                                             34.728606
# Longitude                                           -76.639015
# Name: 390, dtype: object
# County                                                CARTERET
# Address      DAVIS VOLUNTEER FIRE DEPARTMENT, 595 HIGHWAY 7...
# Latitude                                             34.799532
# Longitude                                           -76.462143
# Name: 395, dtype: object
# County                                                CARTERET
# Address      FORT BENJAMIN PARK RECREATION CENTER, 100 MCQU...
# Latitude                                             34.769079
# Longitude                                           -76.858277
# Name: 396, dtype: object
# County                                                CARTERET
# Address      MOREHEAD PARKS AND RECREATION, 1600 FISHER ST,...
# Latitude                                             34.724542
# Longitude                                           -76.724408
# Name: 406, dtype: object
# County                                                CARTERET
# Address      WESTERN PARK COMMUNITY CENTER, 275 OLD HIGHWAY...
# Latitude                                             34.694256
# Longitude                                           -77.072861
# Name: 408, dtype: object
# County                                                 CASWELL
# Address      CASWELL COUNTY BOARD OF ELECTIONS OFFICE, 140 ...
# Latitude                                             36.404345
# Longitude                                           -79.337166
# Name: 418, dtype: object
# County                                                 CASWELL
# Address      CHERRY GROVE RURITAN CLUB, 7152 CHERRY GROVE R...
# Latitude                                              36.30577
# Longitude                                           -79.467532
# Name: 427, dtype: object
# County                                                 CASWELL
# Address      LEASBURG FIRE DEPARTMENT, 5783 NC HIGHWAY 119 ...
# Latitude                                             36.403661
# Longitude                                           -79.214296
# Name: 429, dtype: object
# County                                                 CASWELL
# Address      PELHAM FIRE DEPARTMENT, 4895 OLD US HIGHWAY 29...
# Latitude                                             36.502702
# Longitude                                           -79.474387
# Name: 431, dtype: object
# County                                                 CATAWBA
# Address      CONOVER STATION, 403 CONOVER STATION SE, CONOV...
# Latitude                                              35.70178
# Longitude                                           -81.218879
# Name: 433, dtype: object
# County                                                 CATAWBA
# Address      HIGHLAND RECREATION CENTER, 1451 8TH ST DR NE,...
# Latitude                                             35.748209
# Longitude                                           -81.317527
# Name: 440, dtype: object
# County                                               CATAWBA
# Address      MAIN LIBRARY, 115 WEST 'C' ST, NEWTON, NC 28658
# Latitude                                           35.661449
# Longitude                                          -81.22462
# Name: 451, dtype: object
# County                                                 CATAWBA
# Address      SHERRILLS FORD-TERRELL BRANCH LIBRARY, 9154 SH...
# Latitude                                             35.591635
# Longitude                                           -80.979035
# Name: 460, dtype: object
# County                                                 CATAWBA
# Address      SOUTHWEST LIBRARY, 2944 S NC 127 HWY, HICKORY,...
# Latitude                                             35.692502
# Longitude                                           -81.356332
# Name: 467, dtype: object
# County                                                 CHATHAM
# Address      CCCC HEALTH SCIENCE BUILDING, 75 BALLENTRAE CT...
# Latitude                                             35.814081
# Longitude                                           -79.089616
# Name: 474, dtype: object
# County                                                 CHATHAM
# Address      CHATHAM COUNTY BOARD OF ELECTIONS OFFICE, 984 ...
# Latitude                                             35.720506
# Longitude                                           -79.160453
# Name: 478, dtype: object
# County                                                 CHATHAM
# Address      CHATHAM COUNTY BOARD OF ELECTIONS OFFICE, 984 ...
# Latitude                                             35.720506
# Longitude                                           -79.160453
# Name: 479, dtype: object
# County                                                 CHATHAM
# Address      GOLDSTON ONE STOP, 40 CORAL AVE # A, GOLDSTON,...
# Latitude                                              35.59042
# Longitude                                            -79.32754
# Name: 485, dtype: object
# County                                                 CHATHAM
# Address      GOLDSTON TOWN HALL, 40A CORAL AVE, GOLDSTON, N...
# Latitude                                             35.590429
# Longitude                                           -79.327412
# Name: 489, dtype: object
# County                                                 CHATHAM
# Address      GOVERNORS VILLAGE, 40150 MORING, CHAPEL HILL, ...
# Latitude                                             35.854872
# Longitude                                           -79.024181
# Name: 492, dtype: object
# County                                                 CHATHAM
# Address      NEW HOPE BAPTIST CHURCH, 581 NEW HOPE CHURCH R...
# Latitude                                             35.819797
# Longitude                                           -78.955444
# Name: 493, dtype: object
# County                                                 CHATHAM
# Address      NORTH CHATHAM BRIAR CHAPEL PARK, 1015 ANDREWS ...
# Latitude                                             35.811369
# Longitude                                           -79.109188
# Name: 496, dtype: object
# County                                                 CHATHAM
# Address      NORTH CHATHAM, 5408 BIG WOODS RD, CHAPEL HILL,...
# Latitude                                             35.811028
# Longitude                                            -79.03266
# Name: 497, dtype: object
# County                                                 CHATHAM
# Address      ONE STOP SILER CITY, 111 S THIRD AVE, SILER CI...
# Latitude                                              35.72271
# Longitude                                           -79.459643
# Name: 499, dtype: object
# County                                                 CHATHAM
# Address      PAUL BRAXTON GYM, 115 S 3RD AVE, SILER CITY, N...
# Latitude                                             35.722368
# Longitude                                           -79.459358
# Name: 501, dtype: object
# County                                                 CHATHAM
# Address      SILER CITY COMMUNITY CENTER, 111S THIRD AVE, S...
# Latitude                                             35.722716
# Longitude                                            -79.45963
# Name: 502, dtype: object
# County                                                 CHATHAM
# Address      SILER CITY, 111 S THIRD AVE, SILER CITY, NC 27344
# Latitude                                              35.72271
# Longitude                                           -79.459643
# Name: 503, dtype: object
# County                                                 CHATHAM
# Address      SILER CITY, 115 S THIRD AVE, SILER CITY, NC 27344
# Latitude                                             35.722368
# Longitude                                           -79.459358
# Name: 504, dtype: object
# County                                                CHEROKEE
# Address      CHEROKEE COUNTY BOARD OF ELECTIONS OFFICE, 40 ...
# Latitude                                             35.087131
# Longitude                                           -84.033986
# Name: 506, dtype: object
# County                                                  CHOWAN
# Address      CHOWAN COUNTY BOARD OF ELECTIONS OFFICE, 730 N...
# Latitude                                             36.069377
# Longitude                                           -76.607881
# Name: 514, dtype: object
# County                                                  CHOWAN
# Address      CHOWAN COUNTY BOARD OF ELECTIONS OFFICE, 730 N...
# Latitude                                             36.069377
# Longitude                                           -76.607881
# Name: 517, dtype: object
# County                                                  CHOWAN
# Address      NORTHERN CHOWAN COMM CENTER, 2869 VIRGINIA RD,...
# Latitude                                             36.235048
# Longitude                                           -76.655517
# Name: 522, dtype: object
# County                                                  CHOWAN
# Address      OLD D F WALKER GYMNASIUM REAR ENTRANCE, 112 BL...
# Latitude                                             36.068424
# Longitude                                           -76.600498
# Name: 524, dtype: object
# County                                                    CLAY
# Address      CLAY COUNTY BOARD OF ELECTIONS OFFICE, 54 CHUR...
# Latitude                                             35.046129
# Longitude                                            -83.81752
# Name: 525, dtype: object
# County                                                    CLAY
# Address      CLAY COUNTY BOARD OF ELECTIONS OFFICE, 75 RIVE...
# Latitude                                             35.047737
# Longitude                                           -83.816295
# Name: 531, dtype: object
# County                                                    CLAY
# Address      CLAY COUNTY BOARD OF ELECTIONS OFFICE, 75 RIVE...
# Latitude                                             35.047737
# Longitude                                           -83.816295
# Name: 532, dtype: object
# County                                               CLEVELAND
# Address      BETHEL BAPTIST CHURCH, 606 S DEKALB ST, SHELBY...
# Latitude                                             35.283811
# Longitude                                           -81.538441
# Name: 533, dtype: object
# County                                               CLEVELAND
# Address      BOILING SPRINGS TOWN HALL (NEW), 114 E COLLEGE...
# Latitude                                             35.250109
# Longitude                                           -81.665418
# Name: 535, dtype: object
# County                                               CLEVELAND
# Address      CLEVELAND COUNTY BOARD OF ELECTIONS, OFFICE, 2...
# Latitude                                             35.289592
# Longitude                                           -81.534508
# Name: 539, dtype: object
# County                                               CLEVELAND
# Address      EUGENIA H. YOUNG MEMORIAL LIBRARY, 104 HOWIE D...
# Latitude                                             35.293067
# Longitude                                           -81.555752
# Name: 543, dtype: object
# County                                               CLEVELAND
# Address      H. LAWRENCE PATRICK SENIOR CENTER, 909 E KING ...
# Latitude                                             35.242128
# Longitude                                           -81.325065
# Name: 545, dtype: object
# County                                               CLEVELAND
# Address      H. LAWRENCE PATRICK SENIOR CENTER, 909 E KINGS...
# Latitude                                             35.242128
# Longitude                                           -81.325065
# Name: 548, dtype: object
# County                                               CLEVELAND
# Address      KINGS MOUNTAIN FIRE MUSEUM, 269 CLEVELAND AVE,...
# Latitude                                             35.244805
# Longitude                                           -81.331485
# Name: 549, dtype: object
# County                                               CLEVELAND
# Address      MARKET PLACE SHOPPING CENTER, 1740 E DIXON BLV...
# Latitude                                              35.27091
# Longitude                                           -81.500039
# Name: 551, dtype: object
# County                                               CLEVELAND
# Address      MARKET PLACE SHOPPING CENTER, 1744 E DIXON BLV...
# Latitude                                             35.272599
# Longitude                                           -81.501152
# Name: 552, dtype: object
# County                                               CLEVELAND
# Address      MT. ZION BAPTIST CHURCH, 220 N WATTERSON ST, K...
# Latitude                                             35.243334
# Longitude                                           -81.349866
# Name: 553, dtype: object
# County                                               CLEVELAND
# Address      PALM TREE UNITED METHODIST CHURCH., 1160 W STA...
# Latitude                                              35.41529
# Longitude                                           -81.585818
# Name: 555, dtype: object
# County                                               CLEVELAND
# Address      THE LEGRAND CENTER, 1800 E MARION ST, SHELBY, ...
# Latitude                                             35.277975
# Longitude                                           -81.489806
# Name: 556, dtype: object
# County                                             COLUMBUS
# Address      BOLTON TOWN HALL, 221 9TH ST, BOLTON, NC 28423
# Latitude                                          34.320322
# Longitude                                        -78.407326
# ...
# Latitude                                             35.862236
# Longitude                                           -78.644395
# Name: 2525, dtype: object
# County                                                    WAKE
# Address      RB - ROBERTS COMMUNITY CENTER, 1300 E MARTIN S...
# Latitude                                              35.77552
# Longitude                                           -78.617863
# Name: 2527, dtype: object
# County                                                    WAKE
# Address      SOUTHEAST RALEIGH YMCA, 1436 ROCK QUARRY RD, R...
# Latitude                                             35.760161
# Longitude                                           -78.616577
# Name: 2531, dtype: object
# County                                                    WAKE
# Address      TA - NCSU TALLEY STUDENT CENTER, 2411 DUNN AVE...
# Latitude                                             35.783648
# Longitude                                           -78.669835
# Name: 2532, dtype: object
# County                                                    WAKE
# Address      TA - NCSU TALLEY STUDENT CENTER, 2610 CATES AV...
# Latitude                                              35.78401
# Longitude                                           -78.670987
# Name: 2534, dtype: object
# County                                                    WAKE
# Address      TRIANGLE CHRISTIAN CENTER, 11100 FELLOWSHIP DR...
# Latitude                                             35.920174
# Longitude                                           -78.803486
# Name: 2536, dtype: object
# County                                                    WAKE
# Address      WA - WAKE TECH COMMUNITY COLLEGE, 9101 FAYETTE...
# Latitude                                              35.65091
# Longitude                                           -78.704012
# Name: 2537, dtype: object
# County                                                    WAKE
# Address      WA - WAKE TECH COMMUNITY COLLEGE, 9101 FAYETTE...
# Latitude                                              35.65091
# Longitude                                           -78.704012
# Name: 2538, dtype: object
# County                                                    WAKE
# Address      WAKE COUNTY BOARD OF ELECTIONS OFFICE, 1200 N ...
# Latitude                                             35.795845
# Longitude                                           -78.561336
# Name: 2540, dtype: object
# County                                                    WAKE
# Address      WAKE COUNTY BOARD OF ELECTIONS OFFICE, 337 S S...
# Latitude                                             35.775885
# Longitude                                           -78.640007
# Name: 2545, dtype: object
# County                                                    WAKE
# Address      WD - WENDELL COMMUNITY CENTER, 601 W THIRD ST,...
# Latitude                                             35.782383
# Longitude                                           -78.381477
# Name: 2552, dtype: object
# County                                                    WAKE
# Address      WO - W.O. COUNCIL GYM, 106 N ENNIS ST, FUQUAY ...
# Latitude                                             35.584838
# Longitude                                           -78.792732
# Name: 2554, dtype: object
# County                                                    WAKE
# Address      ZB - ZEBULON - EASTERN REGIONAL CENTER, 1002 D...
# Latitude                                             35.837222
# Longitude                                           -78.319765
# Name: 2556, dtype: object
# County                                                  WARREN
# Address      VAUGHAN ELEMENTARY SCHOOL, 2936 E HIGHWAY 158 ...
# Latitude                                             36.421538
# Longitude                                           -77.998879
# Name: 2558, dtype: object
# County                                                  WARREN
# Address      WARREN COUNTY BOARD OF ELECTIONS OFFICE, 309 N...
# Latitude                                             36.403027
# Longitude                                           -78.153905
# Name: 2559, dtype: object
# County                                              WASHINGTON
# Address      COMMISSIONER ROOM, 116 ADAMS ST, PLYMOUTH, NC ...
# Latitude                                             35.867271
# Longitude                                            -76.74896
# Name: 2568, dtype: object
# County                                              WASHINGTON
# Address      ROANOKE RIVER MARITIME MUSEUM, 206 W WATER ST,...
# Latitude                                             35.866143
# Longitude                                           -76.752905
# Name: 2570, dtype: object
# County                                              WASHINGTON
# Address      WASHINGTON COUNTY BOARD OF ELECTIONS, OFFICE, ...
# Latitude                                              35.87879
# Longitude                                            -76.61654
# Name: 2571, dtype: object
# County                                              WASHINGTON
# Address      WASHINGTON COUNTY BOARD OF ELECTIONS, OFFICE, ...
# Latitude                                             35.867271
# Longitude                                            -76.74896
# Name: 2572, dtype: object
# County                                              WASHINGTON
# Address      WASHINGTON COUNTY ROPER ANNEX, 100 NC HWY 32 N...
# Latitude                                              35.87879
# Longitude                                            -76.61654
# Name: 2577, dtype: object
# County                                                 WATAUGA
# Address      ASU STUDENT UNION, 263 LOCUST ST, BOONE, NC 28608
# Latitude                                             36.214516
# Longitude                                           -81.678183
# Name: 2578, dtype: object
# County                                                 WATAUGA
# Address      BLOWING ROCK CLUB HOUSE, 108 LAKESIDE DR, BLOW...
# Latitude                                             36.135318
# Longitude                                           -81.681767
# Name: 2586, dtype: object
# County                                                 WATAUGA
# Address      BLOWING ROCK TOWN HALL, 1036 MAIN ST, BLOWING ...
# Latitude                                              36.13359
# Longitude                                           -81.678451
# Name: 2588, dtype: object
# County                                                 WATAUGA
# Address      DEEP GAP FIRE DEPT, 6583 OLD 421 SOUTH, DEEP G...
# Latitude                                             36.242519
# Longitude                                           -81.537123
# Name: 2593, dtype: object
# County                                                 WATAUGA
# Address      HIGH COUNTRY VACATION HOMES, 520 CHURCH RD, BO...
# Latitude                                             36.157465
# Longitude                                           -81.771225
# Name: 2600, dtype: object
# County                                                 WATAUGA
# Address      MEAT CAMP FIRE DEPARTMENT, 4797 NC HWY 194 N, ...
# Latitude                                             36.272972
# Longitude                                           -81.650717
# Name: 2602, dtype: object
# County                                                 WATAUGA
# Address      PLEMMONS STUDENT UNION, 263 LOCUST ST, BOONE, ...
# Latitude                                             36.214516
# Longitude                                           -81.678183
# Name: 2608, dtype: object
# County                                                 WATAUGA
# Address      WATAUGA COUNTY ADMINISTRATION BUILDING, 814 W ...
# Latitude                                             36.220235
# Longitude                                           -81.686237
# Name: 2609, dtype: object
# County                                                 WATAUGA
# Address      WESTERN WATAUGA COMM. CENTER, 1081 OLD US HWY ...
# Latitude                                             36.265699
# Longitude                                            -81.78353
# Name: 2618, dtype: object
# County                                                   WAYNE
# Address      FREMONT TOWN HALL, 120 E MAIN ST, FREMONT, NC ...
# Latitude                                             35.543616
# Longitude                                           -77.974356
# Name: 2625, dtype: object
# County                                                   WAYNE
# Address      GOLDSBORO WORSHIP CENTER, 900 W NEW HOPE RD, G...
# Latitude                                             35.402124
# Longitude                                           -77.932555
# Name: 2626, dtype: object
# County                                                   WAYNE
# Address      HARMONY LODGE #340, 108 SW RAILROAD ST, PIKEVI...
# Latitude                                             35.496669
# Longitude                                            -77.98388
# Name: 2627, dtype: object
# County                                           WAYNE
# Address      LIBRARY, 1001 ASH ST, GOLDSBORO, NC 27530
# Latitude                                     35.381887
# Longitude                                   -77.980248
# Name: 2630, dtype: object
# County                                             WAYNE
# Address      LIBRARY, 1001 E ASH ST, GOLDSBORO, NC 27530
# Latitude                                       35.381885
# Longitude                                     -77.980245
# Name: 2634, dtype: object
# County                                                   WAYNE
# Address      LITTLE RIVER SHOPPING CENTER, 1312 W GRANTHAM ...
# Latitude                                             35.399584
# Longitude                                           -78.017107
# Name: 2638, dtype: object
# County                                                   WAYNE
# Address      MAXWELL CENTER, 3114 WAYNE MEMORIAL DR, GOLDSB...
# Latitude                                             35.405461
# Longitude                                           -77.944283
# Name: 2639, dtype: object
# County                                                   WAYNE
# Address      MOUNT OLIVE CIVIC CENTER, 110 W MAIN ST, MT OL...
# Latitude                                             35.196299
# Longitude                                           -78.067477
# Name: 2641, dtype: object
# County                                                   WAYNE
# Address      MOUNT OLIVE TRAIN DEPOT, 110 W MAIN STREET, MT...
# Latitude                                             35.196299
# Longitude                                           -78.067477
# Name: 2643, dtype: object
# County                                                   WAYNE
# Address      NEW HOPE FRIENDS CHURCH, 4451 E US 70 HWY, GOL...
# Latitude                                              35.34502
# Longitude                                           -77.912757
# Name: 2647, dtype: object
# County                                                   WAYNE
# Address      WAYNE COMMUNITY COLLEGE, 3000 WAYNE MEMORIAL D...
# Latitude                                              35.40295
# Longitude                                           -77.945755
# Name: 2648, dtype: object
# County                                                   WAYNE
# Address      WAYNE COUNTY BOARD OF ELECTIONS OFFICE, 209 S ...
# Latitude                                              35.38036
# Longitude                                              -77.995
# Name: 2649, dtype: object
# County                                                  WILKES
# Address      EDWIN MCGEE NATURAL RESOURCE CENTER, 928 FAIRP...
# Latitude                                             36.195425
# Longitude                                           -81.139213
# Name: 2651, dtype: object
# County                                                  WILKES
# Address      MILLERS CREEK FIRE DEPARTMENT, 5132 BOONE TRL,...
# Latitude                                             36.187484
# Longitude                                            -81.23478
# Name: 2653, dtype: object
# County                                                  WILKES
# Address      MILLERS CREEK, 5200 BOONE TRL TRL, MILLERS CRE...
# Latitude                                             36.188088
# Longitude                                           -81.235275
# Name: 2655, dtype: object
# County                                                  WILKES
# Address      MOUNTAIN VIEW RURITAN BUILDING, 5504 MOUNTAIN ...
# Latitude                                             36.249719
# Longitude                                           -81.115776
# Name: 2656, dtype: object
# County                                                  WILKES
# Address      MULBERRY FAIRPLAINS FIRE DEPARTMENT, 2055 SPAR...
# Latitude                                             36.222185
# Longitude                                           -81.170282
# Name: 2657, dtype: object
# County                                                  WILKES
# Address      PLEASANT HILL FIRE DEPARTMENT, 1069 AUSTIN TRA...
# Latitude                                             36.259336
# Longitude                                           -80.891519
# Name: 2658, dtype: object
# County                                                  WILKES
# Address      WILKES COUNTY BOARD OF ELECTIONS OFFICE, 110 N...
# Latitude                                             36.149105
# Longitude                                           -81.153576
# Name: 2660, dtype: object
# County                                                  WILKES
# Address      WILKES COUNTY BOARD OF ELECTIONS OFFICE, 110 N...
# Latitude                                             36.149218
# Longitude                                           -81.153473
# Name: 2663, dtype: object
# County                                                  WILKES
# Address      WILKESBORO CIVIC CENTER, 1241 SCHOOL ST, WILKE...
# Latitude                                              36.13461
# Longitude                                           -81.176257
# Name: 2668, dtype: object
# County                                                  WILSON
# Address      COUNTY ADMIN BUILDING, 2201 MILLER RD, WILSON,...
# Latitude                                             35.698393
# Longitude                                           -77.923843
# Name: 2669, dtype: object
# County                                                  WILSON
# Address      LIDA BLALOCK BUILDING, 1801 GLENDALE DR, WILSO...
# Latitude                                              35.71654
# Longitude                                            -77.94479
# Name: 2671, dtype: object
# County                                                  WILSON
# Address      WILSON COUNTY BOARD OF ELECTIONS OFFICE, 112 D...
# Latitude                                             35.724514
# Longitude                                           -77.908293
# Name: 2673, dtype: object
# County                                                  WILSON
# Address      WILSON COUNTY RESCUE BUILDING, 1902 TARBORO ST...
# Latitude                                             35.719663
# Longitude                                            -77.95058
# Name: 2682, dtype: object
# County                                                  WILSON
# Address      WILSON RESCUE SQUAD BUILDING, 1902 TARBORO ST ...
# Latitude                                             35.720354
# Longitude                                            -77.95053
# Name: 2683, dtype: object
# County                                                  YADKIN
# Address      AGRICULTURAL AND EDUCATIONAL BUILDING, 2051 AG...
# Latitude                                             36.147609
# Longitude                                           -80.674912
# Name: 2684, dtype: object
# County                                                  YADKIN
# Address      YADKIN COUNTY BOARD OF ELECTIONS OFFICE, 213 E...
# Latitude                                             36.134209
# Longitude                                           -80.657966
# Name: 2685, dtype: object
# County                                                  YANCEY
# Address      YANCEY COUNTY BOARD OF ELECTIONS OFFICE, 30 EA...
# Latitude                                             35.917336
# Longitude                                           -82.300961
# Name: 2693, dtype: object
# Isochrones created and saved to 30_min_walking.geojson

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
from tqdm.notebook import tqdm

# %%
polygons = gpd.read_file('30_min_walking.geojson')  # or 'your_polygons.shp' for Shapefile
polygons['point_count'] = 0  # Initialize the count column

# %%
total_rows = sum(1 for row in open('all_snapshot_geocoded_nodups.csv', 'r'))  # Total number of rows in CSV
chunk_size = 100000  # Adjust based on your system's memory
total_chunks = (total_rows // chunk_size) + (1 if total_rows % chunk_size > 0 else 0)

# %%
with tqdm(total=total_chunks) as pbar:
    for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
        # Convert each chunk of points to a GeoDataFrame
        points_gdf = gpd.GeoDataFrame(chunk, geometry=[Point(xy) for xy in zip(chunk.longitude, chunk.latitude)])
        
        # Spatial join points with polygons to count points in each polygon
        joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
        
        # Update counts
        for index in joined['index_right'].unique():
            polygons.loc[index, 'point_count'] += joined[joined['index_right'] == index].shape[0]
        
        pbar.update(1)  # Update the progress bar
# Out:
#   0%|          | 0/74 [00:00<?, ?it/s]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
# ...
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:2: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv('all_snapshot_geocoded_nodups.csv', chunksize=chunk_size):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_47931/499721510.py:7: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(points_gdf, polygons, how='inner', op='within')

# %%
polygons.to_file('updated_30minwalking_polygons.geojson', driver='GeoJSON')  # or use '.shp' for Shapefile

# %%
# Geocoding VR_Snapshots

# %%
import zipfile
import numpy as np
import os

# %%
columns_to_load = [
    'snapshot_dt',
    'county_id',
    'county_desc',
    'ncid',
    'status_cd',
    'voter_status_desc',
    'house_num',
    'half_code',
    'street_dir',
    'street_name',
    'street_type_cd',
    'street_sufx_cd',
    'unit_designator',
    'unit_num',
    'res_city_desc',
    'state_cd',
    'zip_code',
    'race_code',
    'ethnic_code',
    'party_cd',
    'sex_code',
    'age',
    'birth_place',
    'registr_dt',
    'age_group'
]

# %%
chunk_list = []
chunksize = 2 * 10 ** 6

# %%
zip_file_path = '/Users/klausmayr/Downloads/VR_Snapshot_20221206.zip'
file_name_inside_zip = 'VR_Snapshot_20221206.txt'

# %%
extraction_path = '/Users/klausmayr/Desktop/VR/ev_sites/vr_snapshots/'

# %%
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extract(file_name_inside_zip, extraction_path)

# %%
extracted_file_path = os.path.join(extraction_path, file_name_inside_zip)

# %%
for chunk in pd.read_csv(extracted_file_path, sep='\t', usecols=columns_to_load, chunksize=chunksize, encoding="utf-16"):
    chunk_list.append(chunk)
# Out:
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_75890/729970275.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(extracted_file_path, sep='\t', usecols=columns_to_load, chunksize=chunksize, encoding="utf-16"):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_75890/729970275.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(extracted_file_path, sep='\t', usecols=columns_to_load, chunksize=chunksize, encoding="utf-16"):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_75890/729970275.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(extracted_file_path, sep='\t', usecols=columns_to_load, chunksize=chunksize, encoding="utf-16"):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_75890/729970275.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(extracted_file_path, sep='\t', usecols=columns_to_load, chunksize=chunksize, encoding="utf-16"):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_75890/729970275.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(extracted_file_path, sep='\t', usecols=columns_to_load, chunksize=chunksize, encoding="utf-16"):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_75890/729970275.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(extracted_file_path, sep='\t', usecols=columns_to_load, chunksize=chunksize, encoding="utf-16"):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_75890/729970275.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(extracted_file_path, sep='\t', usecols=columns_to_load, chunksize=chunksize, encoding="utf-16"):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_75890/729970275.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(extracted_file_path, sep='\t', usecols=columns_to_load, chunksize=chunksize, encoding="utf-16"):
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_75890/729970275.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(extracted_file_path, sep='\t', usecols=columns_to_load, chunksize=chunksize, encoding="utf-16"):

# %%
vr_snapshots_selects = pd.concat(chunk_list, ignore_index=True)

# %%
vr_snapshots_selects = vr_snapshots_selects[~vr_snapshots_selects['voter_status_desc'].isin(['REMOVED', 'DENIED'])]

# %%
print(len(vr_snapshots_selects))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(len(vr_snapshots_selects))
#
# NameError: name 'vr_snapshots_selects' is not defined

# %%
# print(vr_snapshots_selects.head().transpose())

# %%
sboe_address_points = pd.read_csv("address/address_points_sboe.txt", sep='\t',
                         names=['index','county_id','county_desc', 'st_address', 'city', 'zip_code','house_num','half_code', 'street_dir',
                               'street_name','street_type_cd','street_sufx_cd', 'lat_feet', 'long_feet', 'latitude','longitude'])
# Out:
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_75890/1402736925.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   sboe_address_points = pd.read_csv("address/address_points_sboe.txt", sep='\t',

# %%
# merge_columns = ['county_desc', 'zip_code', 'house_num','street_name', 'street_type_cd']
merge_columns = ['zip_code', 'house_num','street_name', 'street_type_cd']

# %%
vr_snapshots_selects['house_num'] = vr_snapshots_selects['house_num'].astype(str)
sboe_address_points['house_num'] = sboe_address_points['house_num'].astype(str)
vr_snapshots_selects['zip_code'] = vr_snapshots_selects['zip_code'].astype(str)
sboe_address_points['zip_code'] = sboe_address_points['zip_code'].astype(str)

# %%
vr_snapshots_with_address_points = pd.merge(vr_snapshots_selects, sboe_address_points[['latitude', 'longitude'] + merge_columns], on=merge_columns, how='left')

# %%
# print(vr_snapshots_with_address_points.head().transpose())

# %%
successful_merges = vr_snapshots_with_address_points.dropna(subset=['latitude', 'longitude']).shape[0]

# %%
unsuccessful_merges = vr_snapshots_with_address_points[vr_snapshots_with_address_points['latitude'].isna() & vr_snapshots_with_address_points['longitude'].isna()].shape[0]

print(f"Number of successful merges: {successful_merges}")
print(f"Number of rows without a merge: {unsuccessful_merges}")
# Out:
# Number of successful merges: 7294175
# Number of rows without a merge: 434874

# %%
unsuccessful_merges_df = vr_snapshots_with_address_points[vr_snapshots_with_address_points['latitude'].isna() & vr_snapshots_with_address_points['longitude'].isna()]

# Export these rows to a CSV file
# unsuccessful_merges_df.to_csv('unsuccessful_merges.csv', index=False)

print(f"Exported {len(unsuccessful_merges_df)} rows to 'unsuccessful_merges.csv'")
# Out:
# Exported 434874 rows to 'unsuccessful_merges.csv'

# %%
nconemap_address_points = pd.read_csv("nc_onemap_addresses.csv", sep=',')
# Out:
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_75890/1347259824.py:1: DtypeWarning: Columns (7,9,10,11,13,14,22,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   nconemap_address_points = pd.read_csv("nc_onemap_addresses.csv", sep=',')

# %%
nconemap_address_points = nconemap_address_points.rename(columns={'County': 'county_desc', 'Post_Code': 'zip_code', 'Add_Number': 'house_num', 'St_Name': 'street_name', 'St_PosTyp': 'street_type_cd', 'LSt_PreDir': 'street_dir', 'DDLong': 'longitude', 'DDLat': 'latitude'})

# %%
street_type_mapping = {
    'ROAD': 'RD', 'LANE': 'LN', 'TRAIL': 'TRL', 'ALLEY': 'ALY', 'DRIVE': 'DR',
    'WAY': 'WAY', 'VIEW': 'VW', 'CIRCLE': 'CIR', 'STREET': 'ST', 'AVENUE': 'AVE',
    'SQUARE': 'SQ', 'BOULEVARD': 'BLVD', 'LOOP': 'LOOP', 'MEADOWS': 'MDWS',
    'ACRES': 'AC', 'HOLLOW': 'HOLW', 'FORK': 'FRK', 'RIDGE': 'RDG', 'COVE': 'CV',
    'HILL': 'HL', 'PLACE': 'PL', 'ESTATE': 'EST', 'HILLS': 'HLS', 'KNOLL': 'KNL',
    'COURT': 'CT', 'SPRINGS': 'SPGS', 'ESTATES': 'ESTS', 'PARK': 'PARK',
    'HEIGHTS': 'HTS', 'BEND': 'BND', 'PATH': 'PATH', 'CORNER': 'COR', 'PARKWAY': 'PKWY',
    'HIGHWAY': 'HWY', 'RUN': 'RUN', 'TRACE': 'TRCE', 'VILLAGE': 'VLG', 'BYPASS': 'BYP',
    'TERRACE': 'TER', 'CROSSING': 'XING', 'CREEK': 'CRK', 'PLAZA': 'PLZ', 'BRANCH': 'BR',
    'CENTER': 'CTR', 'MOUNTAIN': 'MTN', 'VALLEY': 'VLY', 'GREEN': 'GRN', 'KNOLLS': 'KNLS',
    'PASS': 'PASS', 'ISLAND': 'IS', 'POINT': 'PT', 'FOREST': 'FRST', 'ROW': 'ROW',
    'FLAT': 'FLT', 'REST': 'RST', 'HAVEN': 'HVN', 'VISTA': 'VIS', 'BLUFF': 'BLF',
    'GROVE': 'GRV', 'FARM': 'FM', 'OVERLOOK': 'OLK', 'POINTE': 'PTE', 'CREST': 'CRST',
    'CONNECTOR': 'CON', 'LANDING': 'LNDG', 'SPUR': 'SPUR', 'CROSS': 'CRS', 'EXTENSION': 'EXT',
    'WYND': 'WYND', 'WALK': 'WALK', 'TURN': 'TURN', 'GLEN': 'GLN', 'OVAL': 'OVL',
    'SHORES': 'SHRS', 'BRIDGE': 'BRG', 'HARBOR': 'HBR', 'FALLS': 'FLS', 'LAKE': 'LK',
    'EXPRESSWAY': 'EXPY', 'GARDEN': 'GDN', 'SPRING': 'SPG', '(GAP)': 'GAP', 'FLAT': 'FLT',
    'REST': 'RST', 'GARDENS': 'GDNS', 'FIELDS': 'FLDS', 'ANNEX': 'ANX', 'BAY': 'BY',
    'MEADOW': 'MDW', 'ORCHARD': 'ORCH', 'MILL': 'ML', 'PIKE': 'PIKE', 'FLATS': 'FLTS',
    'EDGE': 'EDG', 'TURNPIKE': 'TPKE', 'CURVE': 'CURV', 'LODGE': 'LDG', 'COVES': 'CVS',
    'FORD': 'FRD', 'FREEWAY': 'FWY', 'CAUSEWAY': 'CSWY', 'MANOR': 'MNR', 'NECK': 'NCK',
    'CHASE': 'CHSE', 'REACH': 'RCH', 'STATION': 'STA', 'PASSAGE': 'PSG', 'MEWS': 'MEWS',
    'DALE': 'DL', 'COMMON': 'CMN', 'LEDGE': 'LDG', 'COMMONS': 'CMNS'
}

# %%
def rename_street_types(street_rename_df, column_name, mapping):
    street_rename_df[column_name] = street_rename_df[column_name].map(mapping).fillna(street_rename_df[column_name])
    return street_rename_df

# %%
# Applying the function to your DataFrame
nconemap_address_points = rename_street_types(nconemap_address_points, 'street_type_cd', street_type_mapping)

# %%
nconemap_address_points = nconemap_address_points.dropna(subset=['zip_code', 'house_num'], how='any')

# %%
nconemap_address_points['zip_code'] = nconemap_address_points['zip_code'].astype(str)
nconemap_address_points['house_num'] = nconemap_address_points['house_num'].astype(str)
unsuccessful_merges_df['zip_code'] = unsuccessful_merges_df['zip_code'].astype(str)
unsuccessful_merges_df['house_num'] = unsuccessful_merges_df['house_num'].astype(str)
# Out:
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_75890/514359129.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unsuccessful_merges_df['zip_code'] = nconemap_address_points['zip_code'].astype(str)
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_75890/514359129.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unsuccessful_merges_df['house_num'] = nconemap_address_points['house_num'].astype(str)

# %%
# FOR SOME REASON, MERGING THESE DATAFRAMES IN PYTHON IS NOT WORKING. I EXPORTED THE "unsuccessful_merges_df" AND "nconemap_address_points"
# DATAFRAMES AND DID THE MATCH IN R, WHICH RETURNED MANY MORE MATCHES. THAN IT DID IN PYTHON. NOT SURE WHY. BUT WHILE I FIGURE THAT OUT, 
# I'M JUST LOADING THE R MERGED DATAFRAME HERE:

# nconemap_merges = pd.merge(unsuccessful_merges_df, nconemap_address_points[['latitude', 'longitude'] + merge_columns], on=merge_columns, how='left')
# successful_onemap_merges = nconemap_merges.dropna(subset=['latitude_y', 'longitude_y']).shape[0]

# unsuccessful_onemap_merges = nconemap_merges[nconemap_merges['latitude_y'].isna() & nconemap_merges['longitude_y'].isna()].shape[0]

# print(f"Number of successful merges: {successful_onemap_merges}")
# print(f"Number of rows without a merge: {unsuccessful_onemap_merges}")

# %%
merged_in_r = pd.read_csv("unsuccessful_merges_merged_in_r.csv", sep=',')
# Out:
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_75890/1134228400.py:1: DtypeWarning: Columns (7,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_in_r = pd.read_csv("unsuccessful_merges_merged_in_r.csv", sep=',')

# %%
successful_onemap_merges = merged_in_r.dropna(subset=['latitude.y', 'longitude.y']).shape[0]

unsuccessful_onemap_merges = merged_in_r[merged_in_r['latitude.y'].isna() & merged_in_r['longitude.y'].isna()].shape[0]

print(f"Number of successful merges: {successful_onemap_merges}")
print(f"Number of rows without a merge: {unsuccessful_onemap_merges}")
# Out:
# Number of successful merges: 1330242
# Number of rows without a merge: 182263

# %%
successful_sboe_merges_df = vr_snapshots_with_address_points.dropna(subset=['latitude', 'longitude'])

# %%
successful_sboe_merges_df['latlon_source'] = 'address_points_sboe.txt'
merged_in_r['latlon_source'] = 'AddressNC-addresses-02-21-2024.zip (NC Onemap)'
# Out:
# /var/folders/nq/tndcfcv94ld_dtqs_sgc70000000gq/T/ipykernel_75890/775946757.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   successful_sboe_merges_df['latlon_source'] = 'address_points_sboe.txt'

# %%
successful_sboe_merges_df.head()
# Out:
#   snapshot_dt  county_id county_desc     ncid status_cd voter_status_desc
# 0  2022-12-06          1    ALAMANCE   AA6924         A            ACTIVE  \
# 1  2022-12-06          1    ALAMANCE  AA21151         A            ACTIVE
# 2  2022-12-06          1    ALAMANCE  AA27357         A            ACTIVE
# 3  2022-12-06          1    ALAMANCE  AA27361         A            ACTIVE
# 4  2022-12-06          1    ALAMANCE  AA27366         A            ACTIVE
#
#   house_num half_code street_dir         street_name  ... ethnic_code
# 0      1816                                 EDGEWOOD  ...          NL  \
# 1       705                                CROFTWOOD  ...          NL
# 2       708                                     KECK  ...          UN
# 3       708                                     KECK  ...          NL
# 4      1975                       HAW RIVER-HOPEDALE  ...          NL
#
#   party_cd sex_code age birth_place  registr_dt    age_group   latitude
# 0      UNA        M  75          NC  1968-04-20  Age Over 66  36.041383  \
# 1      UNA        M  86          NC  1964-10-24  Age Over 66  36.099129
# 2      REP        M  69          NC  1972-01-17  Age Over 66  36.106113
# 3      REP        F  74          NC  1973-05-17  Age Over 66  36.106113
# 4      DEM        F  81          NC  1982-09-18  Age Over 66  36.105205
#
#    longitude            latlon_source
# 0 -79.377864  address_points_sboe.txt
# 1 -79.525971  address_points_sboe.txt
# 2 -79.355647  address_points_sboe.txt
# 3 -79.355647  address_points_sboe.txt
# 4 -79.377956  address_points_sboe.txt
#
# [5 rows x 28 columns]

# %%
merged_in_r.head()
# Out:
#   snapshot_dt  county_id county_desc      ncid status_cd voter_status_desc
# 0  2022-12-06          1    ALAMANCE   AA23132         A            ACTIVE  \
# 1  2022-12-06          1    ALAMANCE   AA82195         A            ACTIVE
# 2  2022-12-06          1    ALAMANCE  AA113774         A            ACTIVE
# 3  2022-12-06          1    ALAMANCE  AA145829         A            ACTIVE
# 4  2022-12-06          1    ALAMANCE   AA23053         A            ACTIVE
#
#    house_num half_code street_dir street_name  ... sex_code age  birth_place
# 0       4551       NaN          S   NC HWY 49  ...        M  69           NC  \
# 1       1453       NaN          N   NC HWY 87  ...        U  57          NaN
# 2       2422       NaN          S  NC HWY 119  ...        F  59           NC
# 3       5614       NaN          N   NC HWY 62  ...        M  34           NC
# 4       3542       NaN          S   NC HWY 87  ...        M  82           NC
#
#    registr_dt    age_group latitude.x  longitude.x latitude.y longitude.y
# 0  1972-01-15  Age Over 66        NaN          NaN        NaN         NaN  \
# 1  1992-07-22  Age 41 - 65        NaN          NaN        NaN         NaN
# 2  1999-03-01  Age 41 - 65        NaN          NaN        NaN         NaN
# 3  2006-02-06  Age 26 - 40        NaN          NaN        NaN         NaN
# 4  2016-02-18  Age Over 66        NaN          NaN        NaN         NaN
#
#                                     latlon_source
# 0  AddressNC-addresses-02-21-2024.zip (NC Onemap)
# 1  AddressNC-addresses-02-21-2024.zip (NC Onemap)
# 2  AddressNC-addresses-02-21-2024.zip (NC Onemap)
# 3  AddressNC-addresses-02-21-2024.zip (NC Onemap)
# 4  AddressNC-addresses-02-21-2024.zip (NC Onemap)
#
# [5 rows x 30 columns]

# %%
successful_onemap_merges_df = merged_in_r.dropna(subset=['latitude.y', 'longitude.y'])

# %%
successful_onemap_merges_df = successful_onemap_merges_df.drop(['latitude.x',	'longitude.x'], axis=1)

# %%
successful_onemap_merges_df.head()
# Out:
#    snapshot_dt  county_id county_desc      ncid status_cd voter_status_desc
# 9   2022-12-06          1    ALAMANCE  AA187800         I          INACTIVE  \
# 12  2022-12-06          1    ALAMANCE  AA214087         A            ACTIVE
# 15  2022-12-06          1    ALAMANCE  BY351338         A            ACTIVE
# 16  2022-12-06          1    ALAMANCE  BY351338         A            ACTIVE
# 17  2022-12-06          1    ALAMANCE  BY351338         A            ACTIVE
#
#     house_num half_code street_dir          street_name  ... sex_code age
# 9         406       NaN        NaN            TRAIL ONE  ...        F  30  \
# 12        923       NaN          N               MEBANE  ...        M  70
# 15       1720       NaN        NaN  OLD ST MARKS CHURCH  ...        M  53
# 16       1720       NaN        NaN  OLD ST MARKS CHURCH  ...        M  53
# 17       1720       NaN        NaN  OLD ST MARKS CHURCH  ...        M  53
#
#     birth_place  registr_dt    age_group latitude.x  longitude.x latitude.y
# 9            VA  2016-02-18  Age 26 - 40        NaN          NaN  36.073845  \
# 12          NaN  2020-09-25  Age Over 66        NaN          NaN  36.092037
# 15           NC  2014-02-05  Age 41 - 65        NaN          NaN  36.063694
# 16           NC  2014-02-05  Age 41 - 65        NaN          NaN  36.063820
# 17           NC  2014-02-05  Age 41 - 65        NaN          NaN  36.064152
#
#    longitude.y                                   latlon_source
# 9   -79.464180  AddressNC-addresses-02-21-2024.zip (NC Onemap)
# 12  -79.423935  AddressNC-addresses-02-21-2024.zip (NC Onemap)
# 15  -79.510277  AddressNC-addresses-02-21-2024.zip (NC Onemap)
# 16  -79.511055  AddressNC-addresses-02-21-2024.zip (NC Onemap)
# 17  -79.510056  AddressNC-addresses-02-21-2024.zip (NC Onemap)
#
# [5 rows x 30 columns]

# %%
successful_onemap_merges_df = successful_onemap_merges_df.rename(columns={'latitude.y': 'latitude', 'longitude.y': 'longitude'})

# %%
print(successful_onemap_merges_df.columns)
# Out:
# Index(['snapshot_dt', 'county_id', 'county_desc', 'ncid', 'status_cd',
#        'voter_status_desc', 'house_num', 'half_code', 'street_dir',
#        'street_name', 'street_type_cd', 'street_sufx_cd', 'unit_designator',
#        'unit_num', 'res_city_desc', 'state_cd', 'zip_code', 'race_code',
#        'ethnic_code', 'party_cd', 'sex_code', 'age', 'birth_place',
#        'registr_dt', 'age_group', 'latitude', 'longitude', 'latlon_source'],
#       dtype='object')

# %%
print(successful_sboe_merges_df.columns)
# Out:
# Index(['snapshot_dt', 'county_id', 'county_desc', 'ncid', 'status_cd',
#        'voter_status_desc', 'house_num', 'half_code', 'street_dir',
#        'street_name', 'street_type_cd', 'street_sufx_cd', 'unit_designator',
#        'unit_num', 'res_city_desc', 'state_cd', 'zip_code', 'race_code',
#        'ethnic_code', 'party_cd', 'sex_code', 'age', 'birth_place',
#        'registr_dt', 'age_group', 'latitude', 'longitude', 'latlon_source'],
#       dtype='object')

# %%
all_successful_merges_df = pd.concat([successful_sboe_merges_df, successful_onemap_merges_df], ignore_index=True)

# %%
successful_merges = all_successful_merges_df.dropna(subset=['latitude', 'longitude']).shape[0]

unsuccessful_merges = all_successful_merges_df[all_successful_merges_df['latitude'].isna() & all_successful_merges_df['longitude'].isna()].shape[0]

print(f"Number of successful merges: {successful_merges}")
print(f"Number of rows without a merge: {unsuccessful_merges}")
# Out:
# Number of successful merges: 8624417
# Number of rows without a merge: 0

# %%
all_successful_merges_df = all_successful_merges_df.drop_duplicates()

# %%
all_successful_merges_df.shape[0]
# Out:
# 8122405

# %%
all_successful_merges_df.to_csv('all_successful_merges.csv', index=False)

# %%
merged_in_r = merged_in_r.drop(['latitude.x',	'longitude.x'], axis=1)

# %%
merged_in_r = merged_in_r.rename(columns={'latitude.y': 'latitude', 'longitude.y': 'longitude'})

# %%
all_unsuccessful_merges_df = merged_in_r[merged_in_r['latitude'].isna() & merged_in_r['longitude'].isna()]

# %%
all_unsuccessful_merges_df.head()
# Out:
#   snapshot_dt  county_id county_desc      ncid status_cd voter_status_desc
# 0  2022-12-06          1    ALAMANCE   AA23132         A            ACTIVE  \
# 1  2022-12-06          1    ALAMANCE   AA82195         A            ACTIVE
# 2  2022-12-06          1    ALAMANCE  AA113774         A            ACTIVE
# 3  2022-12-06          1    ALAMANCE  AA145829         A            ACTIVE
# 4  2022-12-06          1    ALAMANCE   AA23053         A            ACTIVE
#
#    house_num half_code street_dir street_name  ... ethnic_code party_cd
# 0       4551       NaN          S   NC HWY 49  ...          NL      UNA  \
# 1       1453       NaN          N   NC HWY 87  ...          UN      REP
# 2       2422       NaN          S  NC HWY 119  ...          NL      DEM
# 3       5614       NaN          N   NC HWY 62  ...          NL      REP
# 4       3542       NaN          S   NC HWY 87  ...          UN      UNA
#
#    sex_code age birth_place  registr_dt    age_group latitude longitude
# 0         M  69          NC  1972-01-15  Age Over 66      NaN       NaN  \
# 1         U  57         NaN  1992-07-22  Age 41 - 65      NaN       NaN
# 2         F  59          NC  1999-03-01  Age 41 - 65      NaN       NaN
# 3         M  34          NC  2006-02-06  Age 26 - 40      NaN       NaN
# 4         M  82          NC  2016-02-18  Age Over 66      NaN       NaN
#
#                                     latlon_source
# 0  AddressNC-addresses-02-21-2024.zip (NC Onemap)
# 1  AddressNC-addresses-02-21-2024.zip (NC Onemap)
# 2  AddressNC-addresses-02-21-2024.zip (NC Onemap)
# 3  AddressNC-addresses-02-21-2024.zip (NC Onemap)
# 4  AddressNC-addresses-02-21-2024.zip (NC Onemap)
#
# [5 rows x 28 columns]

# %%
all_unsuccessful_merges_df.to_csv('all_unsuccessful_merges.csv', index=False)

# %%
csv_path = 'ev_site_raw_data.csv'
data_csv = pd.read_csv(csv_path)

# Extract unique dates from the 'election' field
unique_dates_csv = sorted(data_csv['election'].unique())

unique_dates_csv
# Out:
# ['2016-11',
#  '2017-10',
#  '2018-05',
#  '2018-11',
#  '2019-09',
#  '2019-10',
#  '2019-11',
#  '2020-03',
#  '2020-06',
#  '2020-11',
#  '2021-10',
#  '2021-11',
#  '2022-05',
#  '2022-07',
#  '2022-11']

# %%
# MERGING EXISTING VR SNAPSHOT FILES
